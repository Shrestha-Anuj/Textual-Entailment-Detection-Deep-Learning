# %% [markdown]
# # splitting the dataset

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# loading dataset for splitting
data_frame = pd.read_csv('df_train.csv')

data_frame
# Out:
#                                                     text1  \
# 0       Conceptually cream skimming has two basic dime...
# 1       you know during the season and i guess at at y...
# 2       One of our number will carry out your instruct...
# 3       How do you know? All this is their information...
# 4       yeah i tell you what though if you go price so...
# ...                                                   ...
# 392697    Clearly, California can - and must - do better.
# 392698  It was once regarded as the most beautiful str...
# 392699  Houseboats are a beautifully preserved traditi...
# 392700  Obituaries fondly recalled his on-air debates ...
# 392701  in that other you know uh that i should do it ...
#
#                                                     text2  label     idx  \
# 0       Product and geography are what make cream skim...      1       0
# 1       You lose the things to the following level if ...      0       1
# ...

# %%
# Rename multiple columns
def reName(data_frame):
    data_frame.rename(columns={
        "text1": "premise",
        "text2": "hypothesis"
    }, inplace=True)
    
    return 0

# %%
reName(data_frame)
data_frame
# Out:
#                                                   premise  \
# 0       Conceptually cream skimming has two basic dime...
# 1       you know during the season and i guess at at y...
# 2       One of our number will carry out your instruct...
# 3       How do you know? All this is their information...
# 4       yeah i tell you what though if you go price so...
# ...                                                   ...
# 392697    Clearly, California can - and must - do better.
# 392698  It was once regarded as the most beautiful str...
# 392699  Houseboats are a beautifully preserved traditi...
# 392700  Obituaries fondly recalled his on-air debates ...
# 392701  in that other you know uh that i should do it ...
#
#                                                hypothesis  label     idx  \
# 0       Product and geography are what make cream skim...      1       0
# 1       You lose the things to the following level if ...      0       1
# ...

# %%
# Split into training and testing sets
train_dataframe, test_dataframe = train_test_split(data_frame, test_size=0.2, random_state=42)

# %%
train_dataframe
# Out:
#                                                   premise  \
# 165213  When agencies lose major accounts, they often ...
# 371699  You think that we are lukewarm, that we lack f...
# 235478  Figure 2: Improved Government Operations Resul...
# 26265       III   There was no delirium when he awoke ...
# 291877  I guess if I go to and fro hustling them, they...
# ...                                                   ...
# 259178  The money is conveyed in easily enough thanks ...
# 365838  i think if you know the cities locally you kno...
# 131932  Somebody MUST have seen her." Forthwith the ca...
# 146867  Time 's cover story is pegged to the release o...
# 121958  Employees who work at alternative work sites s...
#
#                                                hypothesis  label     idx  \
# 165213  People get hired when agencies lose major acco...      2  165213
# 371699  The desk that John and Mr. Wells had been rumm...      2  371699
# ...

# %%
test_dataframe
# Out:
#                                                   premise  \
# 155219                                  That's all right.
# 327538              Televisions are expensive these days.
# 325456  The colonial porte cochre sets the tone for Wa...
# 341461                                  and you just sift
# 54698   You think there's somethin' in all that talk T...
# ...                                                   ...
# 85203   (iv) Other relevant information or requirement...
# 169604  Indeed, so sacred are the Ise shrines that, de...
# 57885   As a great hack once said, the essence of hack...
# 180410  i don't know if every citizen does or not but ...
# 124684  i didn't uh yeah that that i like i like Arkansas
#
#                                                hypothesis  label     idx  \
# 155219                                       That's fine.      0  155219
# 327538  Televisions cost $200 when you purchase them f...      1  327538
# ...

# %%
# rename the validation dataset
validation_data_frame = pd.read_csv('df_validation.csv')
reName(validation_data_frame)

validation_data_frame
# Out:
#                                                 premise  \
# 0                        The new rights are nice enough
# 1     This site includes a list of all award winners...
# 2     uh i don't know i i have mixed emotions about ...
# 3     yeah i i think my favorite restaurant is alway...
# 4            i don't know um do you do a lot of camping
# ...                                                 ...
# 9810  Since 1998, LSC has initiated and overseen sig...
# 9811  Eighty percent of pagers in the United States ...
# 9812  Finally, the FDA will conduct workshops, issue...
# 9813  Cirque du Soleil's The latest from the acclaim...
# 9814  i'll listen  and agree with what i think sound...
#
#                                              hypothesis  label   idx  \
# 0            Everyone really likes the newest benefits       1     0
# 1     The Government Executive articles housed on th...      2     1
# 2     I like him for the most part, but would still ...      0     2
# ...

# %%
train_dataframe.to_csv("splitted_training_data.csv",index=False)
test_dataframe.to_csv("splitted_test_data.csv",index=False)
validation_data_frame.to_csv("validation_data.csv",index=False)

# %%
#datas_frame_train = pd.read_csv('../datasets/train_dataset/sampled_training_data.csv')
#datas_frame_train

# %%
# Sampling for training, validation and testing dataset

#training set
#data_frame_train = pd.read_csv('./splitted_training_data.csv')
#data_frame_train = data_frame_train.sample(frac=0.05, random_state=42) # sampling only 5% of dataset
#data_frame_train.to_csv('./sampled_training_data.csv', index=False) # save the 5% sample as csv

#validation set
#data_frame_validation = pd.read_csv('./validation_data.csv')
#data_frame_validation = data_frame_validation.sample(frac=0.05, random_state=42) # sampling only 5% of dataset
#data_frame_validation.to_csv('./sampled_validation_data.csv', index=False) # save the 5% sample as csv

#testing set
#data_frame_test = pd.read_csv('./splitted_training_data.csv')
#data_frame_test = data_frame_test.sample(frac=0.1, random_state=42) # sampling only 10% of dataset
#data_frame_test.to_csv('./sampled_testing_data.csv', index=False) # save the 10% sample as csv

# %%
# Sampling for training, validation and testing dataset

#training set
#data_frame_train = pd.read_csv('./splitted_training_data.csv')
#data_frame_train = data_frame_train.sample(frac=0.10, random_state=42) # sampling only 10% of dataset
#data_frame_train.to_csv('./sampled_training_data_ten_percent.csv', index=False) # save the 10% sample as csv

#validation set
#data_frame_validation = pd.read_csv('./validation_data.csv')
#data_frame_validation = data_frame_validation.sample(frac=0.10, random_state=42) # sampling only 10% of dataset
#data_frame_validation.to_csv('./sampled_validation_data_ten_percent.csv', index=False) # save the 10% sample as csv

#testing set
#data_frame_test = pd.read_csv('./splitted_training_data.csv')
#data_frame_test = data_frame_test.sample(frac=0.05, random_state=42) # sampling only 5% of dataset
#data_frame_test.to_csv('./sampled_testing_data_five_percent.csv', index=False) # save the 5% sample as csv

# %%
# third mnli sampling
# Sampling for training, validation and testing dataset

#training set
#data_frame_train = pd.read_csv('./splitted_training_data.csv')
#data_frame_train = data_frame_train.sample(frac=0.15, random_state=42) # sampling only 15% of dataset
#data_frame_train.to_csv('./sampled_training_data_fifteen_percent.csv', index=False) # save the 15% sample as csv

#validation set
# use full set for validation
#data_frame_validation = pd.read_csv('./validation_data.csv')
#data_frame_validation.to_csv('./sampled_validation_data_full_percent.csv', index=False) # save the 100% sample as csv

#testing set
#data_frame_test = pd.read_csv('./splitted_training_data.csv')
#data_frame_test = data_frame_test.sample(frac=0.05, random_state=42) # sampling only 5% of dataset
#data_frame_test.to_csv('./sampled_testing_data_five_percent.csv', index=False) # save the 5% sample as csv

# %%
# forth mnli sampling
# Sampling for 30% training, fullset validation and 5% testing dataset

#training set
#data_frame_train = pd.read_csv('./splitted_training_data.csv')
#data_frame_train = data_frame_train.sample(frac=0.3, random_state=42) # sampling only 30% of dataset
#data_frame_train.to_csv('./sampled_training_data_thirty_percent.csv', index=False) # save the 30% sample as csv

#validation set
# use full set for validation
#data_frame_validation = pd.read_csv('./validation_data.csv')
#data_frame_validation.to_csv('./sampled_validation_data_full_percent.csv', index=False) # save the 100% sample as csv

#testing set
#data_frame_test = pd.read_csv('./splitted_training_data.csv')
#data_frame_test = data_frame_test.sample(frac=0.05, random_state=42) # sampling only 5% of dataset
#data_frame_test.to_csv('./sampled_testing_data_five_percent.csv', index=False) # save the 5% sample as csv

# %%
# fifth mnli sampling
# Sampling for second round 30% training, fullset validation and 5% testing dataset

#training set
#data_frame_train = pd.read_csv('./splitted_training_data.csv')
#data_frame_train = data_frame_train.sample(frac=0.3, random_state=42) # sampling only 30% of dataset
#data_frame_train.to_csv('./sampled_training_data_thirty_two_percent.csv', index=False) # save the 30% sample as csv

#validation set
# use full set for validation
#data_frame_validation = pd.read_csv('./validation_data.csv')
#data_frame_validation = data_frame_validation.sample(frac=0.6, random_state=42) # sampling only 60% of dataset
#data_frame_validation.to_csv('./sampled_validation_data_sixty_percent.csv', index=False) # save the 100% sample as csv

#testing set
#data_frame_test = pd.read_csv('./splitted_training_data.csv')
#data_frame_test = data_frame_test.sample(frac=0.05, random_state=42) # sampling only 5% of dataset
#data_frame_test.to_csv('./sampled_testing_data_five_two_percent.csv', index=False) # save the 5% sample as csv

# %%
#training set
data_frame_train = pd.read_csv('./splitted_training_data.csv')
data_frame_train = data_frame_train.sample(frac=0.2, random_state=42) # sampling only 20% of dataset
data_frame_train.to_csv('./sampled_training_data_twenty_percent.csv', index=False) # save the 20% sample as csv
